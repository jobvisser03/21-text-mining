# %%
# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt

import plotly.plotly as py
from plotly.graph_objs import *
import plotly.tools as tls

import pandas as pd
import datetime as dt

# %%
d = pd.read_table('./data_2013.txt', names=["all"])
#d = pd.read_table('./data_2014.txt', names=["all"])

d.head()
d['all']
# Out:
# 0        3/25/13, 14:20 - Willem Bongers changed the su...
# 1         3/25/13, 14:20 - David Chef Berenstein was added
# 2                 3/25/13, 14:20 - Max Moes Osse was added
# 3                 3/25/13, 14:20 - Arjen Franken was added
# 4                   3/25/13, 14:20 - Max Konings was added
# 5                 3/25/13, 14:20 - Joris Schalks was added
# 6                 3/25/13, 14:20 - Maarten Simon was added
# 7              3/25/13, 14:20 - Rick van Nobelen was added
# 8            3/25/13, 14:20 - Timo van Dooremaal was added
# 9                3/25/13, 14:20 - Koen Harthoorn was added
# 10       3/25/13, 14:20 - Joost Gerrie van Thiel was added
# 11                   3/25/13, 14:20 - Job Visser was added
# 12            3/25/13, 14:20 - Werner Hofmeester was added
# 13                3/25/13, 14:20 - David Belgers was added
# 14               3/25/13, 14:20 - Joost Vrijhoef was added
# 15                3/25/13, 14:20 - Frank Rutgers was added
# 16                   3/25/13, 14:20 - Luc Jacobs was added
# 17              3/25/13, 14:20 - Thomas Janssens was added
# 18                     3/25/13, 14:20 - Tom Klyn was added
# 19            4/28/14, 17:15 - Job Visser: <Media omitted>
# 20             4/28/14, 17:15 - Job Visser: Snel stemmen!!
# 21                  4/28/14, 17:17 - Maarten Simon: Hahaha
# 22                 4/28/14, 17:17 - Maarten Simon: Linkje?
# 23       4/28/14, 17:17 - Job Visser: http://studentenh...
# 24       4/28/14, 18:31 - Tom Klyn: Even voor de duidel...
# 25       4/28/14, 20:22 - Timo van Dooremaal: <Media om...
# 26       4/28/14, 20:22 - Timo van Dooremaal: Iedereen ...
# 27       4/28/14, 20:23 - Luc Jacobs: Komen er ook nog ...
# 28       4/29/14, 00:37 - Timo van Dooremaal: Hebben we...
# 29         4/29/14, 00:43 - Timo van Dooremaal: Heb het al
#                                ...
# 24169    1/14/17, 08:08 - Rick van Nobelen: <Media omit...
# 24170         1/14/17, 09:08 - Job Stiev van Geest: Hahaha
# 24171        1/14/17, 10:07 - Max Konings: <Media omitted>
# 24172    1/14/17, 10:23 - Job Stiev van Geest: Is dat h...
# 24173    1/14/17, 10:24 - Lex Willy van Saane: Nee dat ...
# 24174    1/14/17, 10:25 - Job Stiev van Geest: Oeh, dan...
# 24175    1/14/17, 10:25 - Job Stiev van Geest: Die blonde?
# 24176    1/14/17, 10:26 - Lex Willy van Saane: Ja dat z...
# 24177     1/14/17, 10:26 - Job Stiev van Geest: Neeeeetjes
# 24178    1/14/17, 10:27 - Job Stiev van Geest: Geneukse...
# 24179    1/14/17, 10:28 - Lex Willy van Saane: Ja was w...
# 24180    1/14/17, 11:11 - Joost Gerrie van Thiel: Lekke...
# 24181            1/14/17, 11:13 - Max Moes Osse: Beftekkel
# 24182    1/14/17, 11:51 - Grote vriendelijke reus: Volg...
# 24183              1/14/17, 11:51 - Lester Mateboer: Jawel
# 24184    1/14/17, 11:52 - Grote vriendelijke reus: Oh d...
# 24185    1/14/17, 11:56 - Grote vriendelijke reus: Oh w...
# 24186    1/14/17, 11:56 - Grote vriendelijke reus: Jij ...
# 24187    1/14/17, 12:03 - Lars ter Braak: Jezus, heel d...
# 24188    1/14/17, 12:12 - Max Konings: Toen jij samen m...
# 24189    1/14/17, 12:55 - Grote vriendelijke reus: Die ...
# 24190    1/14/17, 13:28 - Lex Willy van Saane: Ook natt...
# 24191    1/14/17, 13:28 - Joost Gerrie van Thiel: En de...
# 24192         1/14/17, 13:33 - Lex Willy van Saane: Nope:(
# 24193             1/14/17, 15:21 - Job Stiev van Geest: 😋💦
# 24194          1/14/17, 15:30 - Max Konings: Aan op de rdb
# 24195    1/14/17, 16:10 - Grote vriendelijke reus: Aan ...
# 24196           1/14/17, 16:15 - ‪+31 6 52187656‬: Ook aan
# 24197    1/15/17, 20:32 - ‪+31 6 14200303‬: Gaan er nog...
# 24198    1/15/17, 21:43 - Max Moes Osse: Ik misschien v...
# Name: all, dtype: object

# %%
d.iloc[9000]
# Out:
# date                        2015-09-26 08:58:00
# name                              Joris Schalks
# message                Wacht gewoon even gerrie
# weekday                                Saturday
# dayhour                                       8
# tokenized_mess    [Wacht, gewoon, even, gerrie]
# mess_length                                   4
# Name: 13014, dtype: object

# %%
# Extract date from messages with regex
d['date'] = d['all'].str.extract("(\d{1,2}/\d{2}/\d{2}, \d{2}:\d{2})", expand=True)

# Parse date as datetime. format: 3/25/13, 14:20
d['date'] = pd.to_datetime(d['date'], format='%m/%d/%y, %H:%M')

# Extract name and message
d['name'] = d['all'].str.extract("(\d{1,2}/\d{2}/\d{2}, \d{2}:\d{2})( -.*?:)(.*)", expand=True)[1].str[3:-1]
d['message'] = d['all'].str.extract("(\d{1,2}/\d{2}/\d{2}, \d{2}:\d{2})( -.*?:)(.*)", expand=True)[2]
d = d.drop('all', 1)

# Include weekday name and hour of day
d['weekday'] = d['date'].dt.weekday_name
d['dayhour'] = d['date'].dt.hour
# Out:
#                      date                     name  \
# 0     2013-03-25 14:20:00                      NaN
# 1     2013-03-25 14:20:00                      NaN
# 2     2013-03-25 14:20:00                      NaN
# 3     2013-03-25 14:20:00                      NaN
# 4     2013-03-25 14:20:00                      NaN
# 5     2013-03-25 14:20:00                      NaN
# 6     2013-03-25 14:20:00                      NaN
# 7     2013-03-25 14:20:00                      NaN
# 8     2013-03-25 14:20:00                      NaN
# 9     2013-03-25 14:20:00                      NaN
# 10    2013-03-25 14:20:00                      NaN
# 11    2013-03-25 14:20:00                      NaN
# 12    2013-03-25 14:20:00                      NaN
# 13    2013-03-25 14:20:00                      NaN
# 14    2013-03-25 14:20:00                      NaN
# 15    2013-03-25 14:20:00                      NaN
# 16    2013-03-25 14:20:00                      NaN
# 17    2013-03-25 14:20:00                      NaN
# 18    2013-03-25 14:20:00                      NaN
# 19    2014-04-28 17:15:00               Job Visser
# 20    2014-04-28 17:15:00               Job Visser
# 21    2014-04-28 17:17:00            Maarten Simon
# 22    2014-04-28 17:17:00            Maarten Simon
# 23    2014-04-28 17:17:00               Job Visser
# 24    2014-04-28 18:31:00                 Tom Klyn
# 25    2014-04-28 20:22:00       Timo van Dooremaal
# 26    2014-04-28 20:22:00       Timo van Dooremaal
# 27    2014-04-28 20:23:00               Luc Jacobs
# 28    2014-04-29 00:37:00       Timo van Dooremaal
# 29    2014-04-29 00:43:00       Timo van Dooremaal
# ...                   ...                      ...
# 24169 2017-01-14 08:08:00         Rick van Nobelen
# 24170 2017-01-14 09:08:00      Job Stiev van Geest
# 24171 2017-01-14 10:07:00              Max Konings
# 24172 2017-01-14 10:23:00      Job Stiev van Geest
# 24173 2017-01-14 10:24:00      Lex Willy van Saane
# 24174 2017-01-14 10:25:00      Job Stiev van Geest
# 24175 2017-01-14 10:25:00      Job Stiev van Geest
# 24176 2017-01-14 10:26:00      Lex Willy van Saane
# 24177 2017-01-14 10:26:00      Job Stiev van Geest
# 24178 2017-01-14 10:27:00      Job Stiev van Geest
# 24179 2017-01-14 10:28:00      Lex Willy van Saane
# 24180 2017-01-14 11:11:00   Joost Gerrie van Thiel
# 24181 2017-01-14 11:13:00            Max Moes Osse
# 24182 2017-01-14 11:51:00  Grote vriendelijke reus
# 24183 2017-01-14 11:51:00          Lester Mateboer
# 24184 2017-01-14 11:52:00  Grote vriendelijke reus
# 24185 2017-01-14 11:56:00  Grote vriendelijke reus
# 24186 2017-01-14 11:56:00  Grote vriendelijke reus
# 24187 2017-01-14 12:03:00           Lars ter Braak
# 24188 2017-01-14 12:12:00              Max Konings
# 24189 2017-01-14 12:55:00  Grote vriendelijke reus
# 24190 2017-01-14 13:28:00      Lex Willy van Saane
# 24191 2017-01-14 13:28:00   Joost Gerrie van Thiel
# 24192 2017-01-14 13:33:00      Lex Willy van Saane
# 24193 2017-01-14 15:21:00      Job Stiev van Geest
# 24194 2017-01-14 15:30:00              Max Konings
# 24195 2017-01-14 16:10:00  Grote vriendelijke reus
# 24196 2017-01-14 16:15:00         ‪+31 6 52187656‬
# 24197 2017-01-15 20:32:00         ‪+31 6 14200303‬
# 24198 2017-01-15 21:43:00            Max Moes Osse
#
#                                                  message   weekday  dayhour
# 0                                                    NaN    Monday     14.0
# 1                                                    NaN    Monday     14.0
# 2                                                    NaN    Monday     14.0
# 3                                                    NaN    Monday     14.0
# 4                                                    NaN    Monday     14.0
# 5                                                    NaN    Monday     14.0
# 6                                                    NaN    Monday     14.0
# 7                                                    NaN    Monday     14.0
# 8                                                    NaN    Monday     14.0
# 9                                                    NaN    Monday     14.0
# 10                                                   NaN    Monday     14.0
# 11                                                   NaN    Monday     14.0
# 12                                                   NaN    Monday     14.0
# 13                                                   NaN    Monday     14.0
# 14                                                   NaN    Monday     14.0
# 15                                                   NaN    Monday     14.0
# 16                                                   NaN    Monday     14.0
# 17                                                   NaN    Monday     14.0
# 18                                                   NaN    Monday     14.0
# 19                                       <Media omitted>    Monday     17.0
# 20                                        Snel stemmen!!    Monday     17.0
# 21                                                Hahaha    Monday     17.0
# 22                                               Linkje?    Monday     17.0
# 23      http://studentenhuisvanhetjaar.nl/verkiezing/...    Monday     17.0
# 24      Even voor de duidelijkheid, OCV is in het sta...    Monday     18.0
# 25                                       <Media omitted>    Monday     20.0
# 26                             Iedereen stoppen met eten    Monday     20.0
# 27                        Komen er ook nog bitterballen?    Monday     20.0
# 28      Hebben we al een keer vluchttijden heen en te...   Tuesday      0.0
# 29                                            Heb het al   Tuesday      0.0
# ...                                                  ...       ...      ...
# 24169                                    <Media omitted>  Saturday      8.0
# 24170                                             Hahaha  Saturday      9.0
# 24171                                    <Media omitted>  Saturday     10.0
# 24172         Is dat het meisje van Caspari?!? De NSB'er  Saturday     10.0
# 24173                       Nee dat is een mobile sjaars  Saturday     10.0
# 24174                                  Oeh, dan zeg ik 👍  Saturday     10.0
# 24175                                        Die blonde?  Saturday     10.0
# 24176                                 Ja dat zie je toch  Saturday     10.0
# 24177                                         Neeeeetjes  Saturday     10.0
# 24178                                       Geneuksekst?  Saturday     10.0
# 24179   Ja was wel mee naar huis, geen neukseks, wel ...  Saturday     10.0
# 24180                                 Lekker natte nagel  Saturday     11.0
# 24181                                          Beftekkel  Saturday     11.0
# 24182   Volgens mij heeft lester ook niet thuis geslapen  Saturday     11.0
# 24183                                              Jawel  Saturday     11.0
# 24184           Oh dan was je goed verstopt in de dekens  Saturday     11.0
# 24185                                           Oh wacht  Saturday     11.0
# 24186                     Jij was aan het blowen beneden  Saturday     11.0
# 24187   Jezus, heel de onder verdieping rook naar wie...  Saturday     12.0
# 24188   Toen jij samen met het wijf van Adje thuis kw...  Saturday     12.0
# 24189                                        Die blonde?  Saturday     12.0
# 24190                              Ook natte mond Gerrie  Saturday     13.0
# 24191                 En de kikkersprong is niet gelukt?  Saturday     13.0
# 24192                                             Nope:(  Saturday     13.0
# 24193                                                 😋💦  Saturday     15.0
# 24194                                      Aan op de rdb  Saturday     15.0
# 24195                                      Aan op de rdb  Saturday     16.0
# 24196                                            Ook aan  Saturday     16.0
# 24197                        Gaan er nog mensen la route    Sunday     20.0
# 24198                              Ik misschien vanavond    Sunday     21.0
#
# [24199 rows x 5 columns]

# %%
# count NaN
pd.isnull(d).sum()
d = d.dropna()

# %%
grp = d.groupby('dayhour')
hour = grp.size().sort_values(ascending=False)
hour
# Out:
# dayhour
# 12.0    1978
# 16.0    1567
# 11.0    1547
# 14.0    1505
# 13.0    1356
# 15.0    1307
# 17.0    1299
# 10.0    1135
# 22.0     849
# 18.0     744
# 21.0     658
# 20.0     605
# 19.0     571
# 9.0      491
# 23.0     486
# 0.0      265
# 8.0      192
# 1.0      139
# 2.0      111
# 3.0      101
# 7.0       38
# 4.0       29
# 5.0       17
# 6.0       12
# dtype: int64

# %%
plt.figure()
hour.plot.bar(alpha=0.5)

# %%
grp = d.groupby(["weekday", 'name'])
weekday = grp.size().sort_values(ascending=False)

# %%
grp = d.groupby("weekday")
weekday = grp.size().sort_values(ascending=False)

# %%
plt.figure()
weekday.plot.bar(alpha=0.5)

# %%
grp = d.groupby("name")
nr_messages = grp.size().sort_values(ascending=False)

# %%
plt.figure()
nr_messages.plot.bar(alpha=0.7)

# %%
d[d['name'] == 'Job Visser'].groupby('weekday').size().sort_values(ascending=False).plot.bar(alpha=0.5, title="Nr. of messages Job")

# %%
d[d['name'] == 'Timo van Dooremaal'].groupby('weekday').size().sort_values(ascending=False).plot.bar(alpha=0.5, title="Nr. of messages Timo")

# %%
d[d['name'] == 'Grote vriendelijke reus'].groupby('weekday').size().sort_values(ascending=False).plot.bar(alpha=0.5, title="Nr. of messages Simon")

# %%
d['message'].iloc[24174]
# Out:
# str

# %%
# Add Emoticon detection

import re

count = len(re.findall(r'[\U0001f600-\U0001f650]', d['message'].iloc[24174]))
count
# Out:
# 0

# %% [markdown]
# ## Text Analytics using NLTK

# %%
import nltk

# %%
t = d[d['name'] == 'Job Visser']['message'].iloc[10]
t
# Out:
# ' Marmeren schaakbord'

# %%
from nltk.probability import FreqDist
words = nltk.tokenize.word_tokenize(text)
fdist = FreqDist(words)

# %%
df = d
#d['tokenized_mess'] = d.apply(lambda row: nltk.word_tokenize(row['message']), axis=1)
df["tokenized_mess"] = df["message"].apply(nltk.word_tokenize)
df['mess_length'] = df.apply(lambda row: len(row['tokenized_mess']), axis=1)
# Out:
# /Users/jobvisser/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/jobvisser/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df.groupby('name')['mess_length'].mean().sort_values(ascending=False).plot.bar(alpha=0.5, title="Average message length")

# %%
df.groupby('dayhour')['mess_length'].mean().sort_values(ascending=False).plot.bar(alpha=0.5, title="Average message length")

# %%
# Join the messages per name and weekday
df.groupby(['name','weekday'])['message'].apply(lambda x: ','.join(x)).reset_index()
dfn = df.groupby(['name'])['message'].apply(lambda x: ','.join(x)).reset_index()
#dfn["tokens"] = df["message"].apply(nltk.word_tokenize)
text = dfn['message'].iloc[6]

# %%
dfn['message'].iloc[6]
# Out:
# ' Ach David stel je niet aan nu heeft ten minste niemand het door als je er niet bent, Hopelijk is hij geen familie van Erik donkers, Er word morgen Spaans in bed gelegen denk ik, Ik meld me aan voor de maaltijd van vanavond, Nee ik ben naar dat college gegaan wat jij ook hebt, Bewaar maar een beetje wodka voor mij, <Media omitted>, Ik denk dat het nu toch echt tijd wordt voor de zomerborrel, Aka losers, Max zelfs je wijf is er bij, Zeker waar, Iemand nu naar huis?, Accepte, Niet bij, Jullie gingen toch met allemaal auto\'s naar sec?, <Media omitted>, Toch te vroeg gewimd, Wie is dat?, Verliefd?, Oh ja nu zie ik het, In Maastricht borrelen lijkt me wel leuk, Vo 13, Koffie go, Gewoon kansen spreiden, Spoelbak, Lounge8, Zo te zien, Ik heb nog 9 eieren die dit weekend over de datum gaan, Neem ik wel mee straks, Misschien streep ik er eerst wel 1 kapot, Ik zag Arie wel met een mobiel naar huis lopen, Volgens mij was het die ene die pas in de kroeg er bij kwam, Open vanaf 12?, <Media omitted>, Bij de ap is het alleen van 8 tot 12 en van 20 tot 22 hemelvaart, Losers, <Media omitted>, Ja melden Vrijhoef!, Kom wel ff langs, MF?, Geen idee maar ik kan maar tot half, Dus prima!, Ik ook aan en te laat, Zit hij al in de app?, Beide niet helaaa, Haha, <Media omitted>, Ik niet, Losers, Wat had ik?, Kut ik had 3 0, Lekker, Fleurig, Je kan hem ook kijken op blendel, Ik eet mee, Leeeeekker, Belachelijk, Haha, Als je het concert wil meemaken wel, Maar als je na de wedstrijd uithaakt kan het nog niet, Dan haal ik morgen middag je kaartje, Ja stond in de voorwaarden bij het bestellen, Ik wist zeker dat ik het daar had gelezen en Tom ook, Dus zou het wel apart zijn als het daar niet heeft gestaan, We halen zo veel mogelijk kaartjes tegelijk om bij elkaar te zitten en gaan denk ik rond half 6 naar binnen, En jij tarzan?, Jij staat op robot mode volgens mij, Voor je kijken doorlopen, Haha, Heerlijk dat kapotte vergiet, Vury nice, Wie kan ik nog machtigen voor de cv?, Of zal ik een ikno vragen?, Zwaai eens, Nee bij Toni is het vriend van vriend, Dat is genoeg, Schitterend, Konings, gefeliciteerd!, Wie heeft er allemaal secret en had die van liselotte bij friend of friend staan?, Dat schijnt, Half 1 ouderejaars lunch, Anciënniteit, <Media omitted>, Frank incognito?, Ja prima, Ik zit nog vol van ontbijt, Ik eet wel wat bij de namiddag koffie, Word er gekookt op den rodenbach?, Ook aan, Zo koffie?, Half ofzo?, Grapje ik ga nu, Wow heftig! Maar hij kon dus nog wel iets nadat het gebeurde?, Is hij naar vught?, Hersenschudding hangt er van af hoe erg, Jij had ook een hersenschudding na je kamerborrel, <Media omitted>, Doe mij ff een clicker, Ja staat er potverdorie al anderhalf uur op!, Niet dat ik weet, Ik heb het niet en algemeen ook niet, Koffie?, Dan ga ik al bijna lunchen, Oh shit ik weer net te lang mijn whatsapp niet gecheckt zo te zien, Ik ga wel ff door, Toch weer geïnstalleerd?, <Media omitted>, 3 potjes in een week heb ik geen problemen mee hoor, Goed bezig stengel?, ! Bedoel ik, 4-1 had geen mens verwacht, Behalve een echte kenner, Ja dat zeg ik, Doe em ff na met pokemons, Prima, Joe, Die is klaar, Ik meld me aan voor het eten vanavond om 7 uur, ga om 8 uur weer naar MF, Job is trouwens echt een sukkel, vinden jullie niet?, Good idea, Ook prima, Ik ga om 14.00 een broodje eten heb zometeen cv check, Haha, Timo kun je kappen met selfies maken van losers zonder whatsapp?, Jojojojo, Ik had niet op team gyros ingezet!, Ah ik zie het, Mijn collega had het verkeerd gehoord, <Media omitted>, Paardelam debuut op nationale tv voor het lempke, Heeft Frank die niet nog?, Wie ik?, Als het even kan willen toni en ik liever studeren in ieder geval, Er waren er ook wel genoeg toch?, John Handcock, Toni frank en ik niet, Ja dat willen we wel, Kunnen max en Arie en gerrie en David en Werner 35 Euro overmaken naar rekeningnummer 15.63.90.914 t.n.v S.M Riezebos?, Prima, Top, <Media omitted>, Nee gewoon casual potjes, Wordt wel laf gekolkt, Zullen we hem dan een n ...

# %%
dfn.loc[(dfn['name'] == 'Job Visser'),'message']
# Out:
# 9     <Media omitted>, Snel stemmen!!, http://stude...
# Name: message, dtype: object

# %%
#text = dfn.loc['name']
text = dfn.loc[(dfn['name'] == 'Job Visser'),'message'].values
text
nltk.tokenize.word_tokenize(text)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-344-52c820eefe6f> in <module>()
#       2 text = dfn.loc[(dfn['name'] == 'Job Visser'),'message'].values
#       3 text
# ----> 4 nltk.tokenize.word_tokenize(text)
#
# /Users/jobvisser/anaconda/lib/python3.5/site-packages/nltk/tokenize/__init__.py in word_tokenize(text, language)
#     104     :param language: the model name in the Punkt corpus
#     105     """
# --> 106     return [token for sent in sent_tokenize(text, language)
#     107             for token in _treebank_word_tokenize(sent)]
#     108
#
# /Users/jobvisser/anaconda/lib/python3.5/site-packages/nltk/tokenize/__init__.py in sent_tokenize(text, language)
#      89     """
#      90     tokenizer = load('tokenizers/punkt/{0}.pickle'.format(language))
# ---> 91     return tokenizer.tokenize(text)
#      92
#      93 # Standard word tokenizer.
#
# /Users/jobvisser/anaconda/lib/python3.5/site-packages/nltk/tokenize/punkt.py in tokenize(self, text, realign_boundaries)
#    1224         Given a text, returns a list of the sentences in that text.
#    1225         """
# -> 1226         return list(self.sentences_from_text(text, realign_boundaries))
#    1227
#    1228     def debug_decisions(self, text):
#
# /Users/jobvisser/anaconda/lib/python3.5/site-packages/nltk/tokenize/punkt.py in sentences_from_text(self, text, realign_boundaries)
#    1272         follows the period.
#    1273         """
# -> 1274         return [text[s:e] for s, e in self.span_tokenize(text, realign_boundaries)]
#    1275
#    1276     def _slices_from_text(self, text):
#
# /Users/jobvisser/anaconda/lib/python3.5/site-packages/nltk/tokenize/punkt.py in span_tokenize(self, text, realign_boundaries)
#    1263         if realign_boundaries:
#    1264             slices = self._realign_boundaries(text, slices)
# -> 1265         return [(sl.start, sl.stop) for sl in slices]
#    1266
#    1267     def sentences_from_text(self, text, realign_boundaries=True):
#
# /Users/jobvisser/anaconda/lib/python3.5/site-packages/nltk/tokenize/punkt.py in <listcomp>(.0)
#    1263         if realign_boundaries:
#    1264             slices = self._realign_boundaries(text, slices)
# -> 1265         return [(sl.start, sl.stop) for sl in slices]
#    1266
#    1267     def sentences_from_text(self, text, realign_boundaries=True):
#
# /Users/jobvisser/anaconda/lib/python3.5/site-packages/nltk/tokenize/punkt.py in _realign_boundaries(self, text, slices)
#    1302         """
#    1303         realign = 0
# -> 1304         for sl1, sl2 in _pair_iter(slices):
#    1305             sl1 = slice(sl1.start + realign, sl1.stop)
#    1306             if not sl2:
#
# /Users/jobvisser/anaconda/lib/python3.5/site-packages/nltk/tokenize/punkt.py in _pair_iter(it)
#     308     """
#     309     it = iter(it)
# --> 310     prev = next(it)
#     311     for el in it:
#     312         yield (prev, el)
#
# /Users/jobvisser/anaconda/lib/python3.5/site-packages/nltk/tokenize/punkt.py in _slices_from_text(self, text)
#    1276     def _slices_from_text(self, text):
#    1277         last_break = 0
# -> 1278         for match in self._lang_vars.period_context_re().finditer(text):
#    1279             context = match.group() + match.group('after_tok')
#    1280             if self.text_contains_sentbreak(context):
#
# TypeError: cannot use a string pattern on a bytes-like object

# %%
import sys
import codecs
import nltk
from nltk.corpus import stopwords

# NLTK's default German stopwords
default_stopwords = set(nltk.corpus.stopwords.words('dutch'))

# We're adding some on our own - could be done inline like this...
custom_stopwords = set((u'omitted', u'media'))
# ... but let's read them from a file instead (one stopword per line, UTF-8)
#stopwords_file = './stopwords.txt'
#custom_stopwords = set(codecs.open(stopwords_file, 'r', 'utf-8').read().splitlines())

all_stopwords = default_stopwords | custom_stopwords

#input_file = sys.argv[1]

#fp = codecs.open(input_file, 'r', 'utf-8')
words = nltk.tokenize.word_tokenize(text)

# Remove single-character tokens (mostly punctuation)
words = [word for word in words if len(word) > 1]

# Remove numbers
words = [word for word in words if not word.isnumeric()]

# Lowercase all words (default_stopwords are lowercase too)
words = [word.lower() for word in words]

# Stemming words seems to make matters worse, disabled
# stemmer = nltk.stem.snowball.SnowballStemmer('german')
# words = [stemmer.stem(word) for word in words]

# Remove stopwords
words = [word for word in words if word not in all_stopwords]


# Calculate frequency distribution
fdist = nltk.FreqDist(words)

# Output top 50 words

for word, frequency in fdist.most_common(50):
    print(u'{};{}'.format(word, frequency))
# Out:
# wel;163
# haha;83
# we;48
# laat;38
# mee;36
# uur;34
# eten;33
# jullie;33
# prima;26
# volgens;25
# kom;25
# even;24
# goed;24
# ga;24
# nee;23
# rodenbach;23
# misschien;22
# weer;22
# weet;22
# koffie;22
# oh;21
# gewoon;21
# gaan;21
# denk;21
# half;20
# zit;19
# mf;19
# lunch;19
# vanavond;18
# net;17
# bier;17
# meld;16
# alleen;15
# jaar;14
# staat;14
# jij;14
# waar;14
# mensen;14
# anders;13
# komt;13
# gaat;13
# beetje;13
# tu;13
# gemini;13
# echt;12
# ok;12
# arie;12
# helaas;12
# komen;12
# eet;12

# %%
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# Exception in thread Thread-5:
# Traceback (most recent call last):
#   File "/Users/jobvisser/anaconda/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/Users/jobvisser/anaconda/lib/python3.5/site-packages/nltk/downloader.py", line 1867, in run
#     for msg in self.data_server.incr_download(self.items):
#   File "/Users/jobvisser/anaconda/lib/python3.5/site-packages/nltk/downloader.py", line 529, in incr_download
#     for msg in self._download_list(info_or_id, download_dir, force):
#   File "/Users/jobvisser/anaconda/lib/python3.5/site-packages/nltk/downloader.py", line 572, in _download_list
#     for msg in self.incr_download(item, download_dir, force):
#   File "/Users/jobvisser/anaconda/lib/python3.5/site-packages/nltk/downloader.py", line 543, in incr_download
#     for msg in self.incr_download(info.children, download_dir, force):
#   File "/Users/jobvisser/anaconda/lib/python3.5/site-packages/nltk/downloader.py", line 529, in incr_download
#     for msg in self._download_list(info_or_id, download_dir, force):
#   File "/Users/jobvisser/anaconda/lib/python3.5/site-packages/nltk/downloader.py", line 572, in _download_list
#     for msg in self.incr_download(item, download_dir, force):
#   File "/Users/jobvisser/anaconda/lib/python3.5/site-packages/nltk/downloader.py", line 549, in incr_download
#     for msg in self._download_package(info, download_dir, force):
#   File "/Users/jobvisser/anaconda/lib/python3.5/site-packages/nltk/downloader.py", line 638, in _download_package
#     for msg in _unzip_iter(filepath, zipdir, verbose=False):
#   File "/Users/jobvisser/anaconda/lib/python3.5/site-packages/nltk/downloader.py", line 2039, in _unzip_iter
#     outfile.write(contents)
# OSError: [Errno 22] Invalid argument
# True
